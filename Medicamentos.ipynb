# %% [markdown]
# **MEDICAMENTOS VITALES NO DISPONIBLES**
#
# ---
#
# *Salud y Protección Social*

# %% [markdown]
# Medicamentos como aquellos indispensables e irremplazables para salvaguardar la vida o aliviar el sufrimiento de un paciente o un grupo de pacientes y que por condiciones de baja rentabilidad en su comercialización, no se encuentran disponibles en el país, o las cantidades no son suficientes.

# %% [markdown]
# https://www.datos.gov.co/Salud-y-Protecci-n-Social/MEDICAMENTOS-VITALES-NO-DISPONIBLES/sdmr-tfmf/about_data

# %%
import pandas as pd
#import matplotlib.pyplot as plt
#import seaborn as sns
#from tabulate import tabulate

# Configuración de estilo de gráficos
#sns.set(style="whitegrid")

# %% [markdown]
# # **DATAFRAME**

# %%
medicamentos = pd.read_csv('MEDICAMENTOS_VITALES_NO_DISPONIBLES.csv')
medicamentos.head()
# Out:
#     FECHA_DE_AUTORIZACIÓN    TIPO_DE_SOLICITUD         SOLICITANTE/IMPORTADOR  \
# 0  10/25/2024 05:00:00 AM   MÁS DE UN PACIENTE    NEXT PHARMA SOURCING S.A.S.
# 1  10/25/2024 05:00:00 AM   MÁS DE UN PACIENTE    NEXT PHARMA SOURCING S.A.S.
# 2  10/25/2024 05:00:00 AM  PACIENTE ESPECIFICO  VALENTECH PHARMA COLOMBIA SAS
# 3  10/25/2024 05:00:00 AM   MÁS DE UN PACIENTE      INMUNOTEK COLOMBIA S.A.S.
# 4  10/25/2024 05:00:00 AM   MÁS DE UN PACIENTE      INMUNOTEK COLOMBIA S.A.S.
#
#                IUM                                  PRINCIPIO_ACTIVO1  \
# 0  1F1062831001100                                          FENITOINA
# 1  1Z1060871000101  HERPES ZOSTER-VARICELLA ZOSTER VIRUS (OKA STRAIN)
# 2  2E1032451000100                   ELEXACAFTOR/TEZACAFTOR/IVACAFTOR
# 3  1A1023311000103                                   APIS MELLIFERA 2
# 4  1A1024551000101                                VESPULA GERMANICA 0
#
#   CONCENTRACIÓN_DELMEDICAMENTO1     UNIDAD_MEDIDA1 PRINCIPIO_ACTIVO2  \
# ...

# %%
medicamentos = medicamentos.drop(['SOLICITANTE/IMPORTADOR', 'PRINCIPIO_ACTIVO2', 'UNIDAD_MEDIDA1', 'FORMA_FARMACÉUTICA', 'CONCENTRACIÓN_DELMEDICAMENTO1', 'UNIDAD_MEDIDA2', 'CONCENTRACIÓN_DEL_MEDICAMENTO2'], axis=1)

medicamentos = medicamentos.rename(columns={
    'FECHA_DE_AUTORIZACIÓN': 'fecha_autori',
    'TIPO_DE_SOLICITUD': 'tip_solic',
    'IUM': 'cod_medicam',
    'PRINCIPIO_ACTIVO1': 'princip_activo',
    'NOMBRE_COMERCIAL_': 'nomb_comerc',
    'CANTIDAD_SOLICITADA': 'cant_solic',
    'PRESENTACIÓN_COMERCIAL': 'present_comerc',
    'DIAGNOSTICO_CIE-1NO REPORTA': 'diagnostico',
    'CÓDIGO_DIAGNOSTICO_CIE-10': 'cod_diagnos'
})

# Convierte la columna a tipo datetime
medicamentos['fecha_autori'] = pd.to_datetime(medicamentos['fecha_autori'])

# Mantén solo la parte de la fecha (sin la hora)
medicamentos['fecha_autori'] = medicamentos['fecha_autori'].dt.date

medicamentos['princip_activo'] = medicamentos['princip_activo'].str.upper()
medicamentos['nomb_comerc'] = medicamentos['nomb_comerc'].str.upper()

medicamentos = medicamentos.dropna(subset=['tip_solic'])
medicamentos = medicamentos.dropna(subset=['cod_medicam'])
medicamentos = medicamentos.dropna(subset=['cant_solic'])
medicamentos = medicamentos.dropna(subset=['present_comerc'])
medicamentos = medicamentos[medicamentos['nomb_comerc'] != 'NO REPORTADO']
medicamentos = medicamentos[medicamentos['nomb_comerc'] != 'NO TIENE']
medicamentos = medicamentos[medicamentos['cod_diagnos'] != 'NO REPORTADO']
medicamentos = medicamentos[medicamentos['diagnostico'] != 'NO REPORTADO']
medicamentos = medicamentos[medicamentos['nomb_comerc'] != 'VARIOS']
medicamentos = medicamentos[medicamentos['nomb_comerc'] != 'NO EXISTE']
medicamentos = medicamentos[medicamentos['nomb_comerc'] != 'ALXOID ORALTEK']

medicamentos['nomb_comerc'] = medicamentos['nomb_comerc'].str.replace('-', ' ')
medicamentos['nomb_comerc'] = medicamentos['nomb_comerc'].str.replace(r'\s+', ' ', regex=True)

medicamentos['princip_activo'] = medicamentos['princip_activo'].str.replace('-', ' ')
medicamentos['princip_activo'] = medicamentos['princip_activo'].str.replace(r'\s+', ' ', regex=True)

reem_prin = {
    'ACIDO QUENODEOXICOLICO': 'ACIDO QUENODESOXICOLICO',
    'BACILLUS CALMETTE GUERIN': 'BACILO CALMETTE GUERIN',
    'PBRONQ/NAS BLOMIA TROP.': 'EXTRACTO ALERGÉNICO DE ÁCARO DEL POLVO',
    'ACARUS SIRO 100%': 'EXTRACTO ALERGÉNICO DE ÁCARO DEL POLVO',
    'PBRONQ/NAS DERM. FARINAE': 'EXTRACTO ALERGÉNICO DE ÁCARO DEL POLVO',
    'PBRONQ/NAS DERM. PTER.': 'EXTRACTO ALERGÉNICO DE ÁCARO DEL POLVO',
    'PBRONQ/NAS EPITELIO DE GATO': 'EXTRACTO ALERGÉNICO DE FELIS DOMESTICUS',
    'PBRONQ/NAS EPITELIO DE PERRO': 'EXTRACTO ALERGÉNICO DE CANIS FAMILIARIS',
    'PBRONQ/NAS GRUPO GRAMÍNEAS': 'EXTRACTO ALERGÉNICO DE GRAMÍNEAS',
    'ALIMENTO EN POLVO NUTRICIONALMENTE COMPLETO CON FINES MEDICOS ESPECIALES PARA EL MANEJO NUTRICIONAL DE LACTANTES Y NIÑOS CON INSUFICIENCIA RENAL CRONICA': 'FÓRMULA METABÓLICA',
    'ALIMENTO ESPECIAL AMINOACIDOS ESENCIALES, CARBOHIDRATOS, VITAMINAS Y MINERALES': 'AMINOÁCIDOS ESENCIALES',
    'DIETA LIBRE DE AMINOACIDOS NO ESENCIALES': 'AMINOÁCIDOS ESENCIALES',
    'DIETA LIBRE DE TIROSINA Y FENILALANINA': 'FÓRMULA METABÓLICA',
    'DILUYENTE (SOLUCIÓN ISOTÓNICA DE CLORURO DE SODIO)': 'DILUYENTE',
    'ALIMENTO ESPECIAL CON AMINOACIDOS MODIFICADOS': 'AMINOÁCIDOS ESENCIALES',
    'MODULO DE ENERGIA LIBRE DE PROTEINAS CON HIERRO, VITAMINAS Y MINERALES': 'AMINOÁCIDOS ESENCIALES',
    'ALIMENTO': 'FÓRMULA METABÓLICA',
    'INMUNOGLOBULINA NORMAL': 'INMUNOGLOBULINA HUMANA NORMAL',
    'L ASPARAGINASA': 'ASPARAGINASA',
    'L ASPARAGINASA (AISLADA DE E. COLI)': 'ASPARAGINASA',
    'INTERFERON ALFA 2 BETA RECOMBINANTE': 'INTERFERON ALFA 2B',
    'INTERFERON ALFA 2 BETA HUMANO RECOMBINANTE': 'INTERFERON ALFA 2B',
    'INTERFERON ALFA 2 BETA': 'INTERFERON ALFA 2B',
    'ASPARAGINASA ERWINIA (CRISANTASPASA)': 'ASPARAGINASA',
    'LUTECIO': '177 LU CLORURO DE LUTECIO 177',
    'ASPARAGINASA (E.COLI)': 'ASPARAGINASA',
    'ASPARAGINASA (AISLADA DE E COLI)': 'ASPARAGINASA',
    'L ASPARAGINASA E. COLI': 'ASPARAGINASA',
    'BETANECOL HCL': 'BETANECOL',
    'EPINEFRINA (ADRENALINA)': 'EPINEFRINA',
    'LIOTIRONINA T3': 'LIOTIRONINA',
    'APIS MELLIFERA 0 (VIALES 1, 2, 3, 4 Y 5)': 'EXTRACTO ALERGÉNICO DE APIS MELLIFERA',
    'APIS MELLIFERA 1 (VIALES 1, 2, 3, 4 Y 5)': 'EXTRACTO ALERGÉNICO DE APIS MELLIFERA',
    'BUSULFANO': 'BUSULFAN',
    'CLOFAZIMINE': 'CLOFAZIMINA',
    'CREATINA MONOHIDRATO': 'CREATINA',
    'D. PTERONYSSINUS 50% + D. FARINAE 50%': 'EXTRACTO ALERGÉNICO DE ÁCARO DEL POLVO',
    'D. PTERONYSSINUS 33,3%, D. FARINAE 33,3%, B. TROPICALIS 33,3%': 'EXTRACTO ALERGÉNICO COMBINADO DE ÁCARO DEL POLVO Y HONGO',
    'D. PTERONYSSINUS 34%, D. FARINAE 33%, B. TROPICALIS 33%': 'EXTRACTO ALERGÉNICO COMBINADO DE ÁCARO DEL POLVO Y HONGO',
    'D. PTERONYSSINUS 33% , D. FARINAE 33%, B. TROPICALIS 33%': 'EXTRACTO ALERGÉNICO COMBINADO DE ÁCARO DEL POLVO Y HONGO',
    'EDARAVONE': 'EDARAVONA',
    'EPITELIO DE PERRO': 'EXTRACTO ALERGÉNICO DE CANIS FAMILIARIS',
    'EPITELIO DE GATO': 'EXTRACTO ALERGÉNICO DE FELIS DOMESTICUS',
    'EPITELIO DE PERRO 100%': 'EXTRACTO ALERGÉNICO DE CANIS FAMILIARIS',
    'EPITELIO DE GATO 100%': 'EXTRACTO ALERGÉNICO DE FELIS DOMESTICUS',
    'FENILBUTIRATO GLICEROL': 'FENILBUTIRATO DE GLICEROL',
    'LUMACAFTOR *': 'LUMACAFTOR',
    'LUSPATERCEPT 25 MG': 'LUSPATERCEPT',
    'LUSPATERCEPT 75 MG': 'LUSPATERCEPT',
    'METRELEPTINA': 'METRELEPTIN',
    'MEZCLA 6 GRAMINEAS 100%': 'EXTRACTO ALERGÉNICO DE GRAMÍNEAS',
    'MITOTANE': 'MITOTANO',
    'NITISINONE': 'NITISINONA',
    'ALERGENO CANIS FAMILIARIS (PERRO EPITELIO 100%)': 'EXTRACTO ALERGÉNICO DE CANIS FAMILIARIS',
    'ALERGENO CANIS FAMILIARIS 100%': 'EXTRACTO ALERGÉNICO DE CANIS FAMILIARIS',
    'ALERGENO DERMATOPHAGOIDES PTERONYSSINUS': 'EXTRACTO ALERGÉNICO DE ÁCARO DEL POLVO',
    'ALERGENO FELIS DOMESTICUS (GATO EPITELIO 100%)': 'EXTRACTO ALERGÉNICO DE FELIS DOMESTICUS',
    'ALERGENO FELIS DOMESTICUS 100%': 'EXTRACTO ALERGÉNICO DE FELIS DOMESTICUS',
    'ALERGENO GRAMINEAS SALVAJES': 'EXTRACTO ALERGÉNICO DE GRAMÍNEAS',
    'ALERGENO GRUPO CUCARACHA (100%)': 'EXTRACTO ALERGÉNICO DE CUCARACHA',
    'ALERGENO SOLENOPSIS SP (HORMIGA 100%)': 'EXTRACTO ALERGÉNICO DE HORMIGA',
    'ALERGENOS DERMATOPHAGOIDES PTERONYSSINUS 100% + DERMATOPHAGOIDES FARINAE 100%': 'EXTRACTO ALERGÉNICO DE ÁCARO DEL POLVO',
    'ALERGENOS DERMATOPHAGOIDES PTERONYSSINUS 50% + DERMATOPHAGOIDES FARINAE 50%': 'EXTRACTO ALERGÉNICO DE ÁCARO DEL POLVO',
    'ALÉRGENOS DERMATOPHAGOIDES PTERONYSSINUS 33,3% + DERMATOPHAGOIDES FARINAE 33,3% + BLOMIA TROPICALIS 33,3%': 'EXTRACTO ALERGÉNICO COMBINADO DE ÁCARO DEL POLVO Y HONGO',
    'EXTRACTO ALERGÉNICO AEDES AEGYPTY (MOSQUITO) 100%': 'EXTRACTO ALERGÉNICO DE MOSQUITO',
    'EXTRACTO ALERGÉNICO BLATELLA GERMANICA 100%': 'EXTRACTO ALERGÉNICO DE CUCARACHA',
    'EXTRACTO ALERGÉNICO CABALLO (EPITELIO) 100%': 'EXTRACTO ALERGÉNICO DE CABALLO',
    'EXTRACTO ALERGÉNICO GATO (EPITELIO) 100%': 'EXTRACTO ALERGÉNICO DE FELIS DOMESTICUS',
    'EXTRACTO ALERGÉNICO GRUPO CUCARACHA 100%': 'EXTRACTO ALERGÉNICO DE CUCARACHA',
    'EXTRACTO ALERGÉNICO HORMIGA 100%': 'EXTRACTO ALERGÉNICO DE HORMIGA',
    'HORMIGA ROJA': 'EXTRACTO ALERGÉNICO DE HORMIGA',
    'HORMONA LIBERADORA DE TIROTROFINA': 'HORMONA LIBERADORA DE TIROTROPINA',
    'PAROTIROIDEA': 'PARATIROIDEA',
    'INHIBIDOR C1 ESTEARASA': 'INHIBIDOR C1 ESTERASA',
    'EXTRACTO ALERGÉNICO MOSQUITO 100%': 'EXTRACTO ALERGÉNICO DE MOSQUITO',
    'APIS MELLIFERA 0': 'EXTRACTO ALERGÉNICO DE APIS MELLIFERA',
    'APIS MELLIFERA 2': 'EXTRACTO ALERGÉNICO DE APIS MELLIFERA',
    'FOLINATO DE CALCIO (ÁCIDO FOLÍNICO)': 'FOLINATO DE CALCIO',
    'INHIBIDOR DE C1 (HUMANO)': 'INHIBIDOR C1 ESTERASA',
    'INHIBIDOR C1 RECOMBINANTE HUMANO/CONESTAT ALFA': 'CONESTAT ALFA (INHIBIDOR C1 RECOMBINANTE HUMANO)',
    'INHIBIDOR C1 RECOMBINANTE/CONESTAT ALFA HUMANO/CONESTAT ALFA': 'CONESTAT ALFA (INHIBIDOR C1 RECOMBINANTE HUMANO)',
    'D. PTERONYSSINUS 33% / D. FARINAE 33% / BLOMINA T 33%':'EXTRACTO ALERGÉNICO DE ÁCARO DEL POLVO',
    'D. PTERONYSSINUS 50% / D. FARINAE 50%': 'EXTRACTO ALERGÉNICO DE ÁCARO DEL POLVO',
    'DERM.PTER. 50% + BLOMIA TROP. 50%': 'EXTRACTO ALERGÉNICO DE ÁCARO DEL POLVO',
    'DERM.PTER. 50% + DERM.FARINAE 50%': 'EXTRACTO ALERGÉNICO DE ÁCARO DEL POLVO',
    'DERM.PTER.34% + DERM.FARINAE 33% + BLOMIA TROP.33%': 'EXTRACTO ALERGÉNICO DE ÁCARO DEL POLVO',
    'DERMATOPHAGOIDES PTERONYSSINUS + DERMATOPHAGOIDES FARINAE (50:50)': 'EXTRACTO ALERGÉNICO DE ÁCARO DEL POLVO',
    'DERMATOPHAGOIDES PTERONYSSINUS + DERMATOPHAGOIDES FARINAE + BLOMIA TROPICALIS (33:33:33)': 'EXTRACTO ALERGÉNICO DE ÁCARO DEL POLVO',
    'DERMATOPHAGOIDES PTERONYSSINUS 33.3% + DERMATOPHAGOIDES FARINAE 33.3%, BLOMIA 33,3%': 'EXTRACTO ALERGÉNICO DE ÁCARO DEL POLVO',
    'EXTRACTO ALERGÉNICO PERRO (EPITELIO) 100%': 'EXTRACTO ALERGÉNICO DE CANIS FAMILIARIS',
    'EXTRACTO ALERGÉNICO SOLENOPSIS SP (HORMIGA) 100%': 'EXTRACTO ALERGÉNICO DE HORMIGA',
    'VESPULA GERMANICA 0': 'EXTRACTO ALERGÉNICO DE AVISPA',
    'VESPULA GERMANICA 2': 'EXTRACTO ALERGÉNICO DE AVISPA',
    'EXTRACTOS ALERGÉNICOS BLOMIA TROPICALIS 100%': 'EXTRACTO ALERGÉNICO DE ÁCARO DEL POLVO',
    'EXTRACTOS ALERGÉNICOS D. FARINAE 100%': 'EXTRACTO ALERGÉNICO DE ÁCARO DEL POLVO',
    'EXTRACTOS ALERGÉNICOS D. PTERONYSSINUS 100%': 'EXTRACTO ALERGÉNICO DE ÁCARO DEL POLVO',
    'EXTRACTOS ALERGÉNICOS EPITELIO DE CABALLO': 'EXTRACTO ALERGÉNICO DE CABALLO',
    'EXTRACTOS ALERGÉNICOS MEZCLA 6 GRAMÍNEAS 100%': 'EXTRACTO ALERGÉNICO DE GRAMÍNEAS',
    'EXTRACTOS ALERGÉNICOS TRATAMIENTO SUBCUTÁNEO DEPIGOID ACARUS SIRO 100%': 'EXTRACTO ALERGÉNICO DE ÁCARO DEL POLVO',
    'EXTRACTOS ALERGÉNICOS TRATAMIENTO SUBCUTÁNEO DEPIGOID BLOMIA TROP. 100%': 'EXTRACTO ALERGÉNICO DE ÁCARO DEL POLVO',
    'EXTRACTOS ALERGÉNICOS TRATAMIENTO SUBCUTÁNEO DEPIGOID CHORTOGLYPHUS ARCUAT 100%': 'EXTRACTO ALERGÉNICO DE ÁCARO DEL POLVO',
    'EXTRACTOS ALERGÉNICOS TRATAMIENTO SUBCUTÁNEO DEPIGOID DERM.PTER. 100%': 'EXTRACTO ALERGÉNICO DE ÁCARO DEL POLVO',
    'EXTRACTOS ALERGÉNICOS TRATAMIENTO SUBCUTÁNEO DEPIGOID DERM.PTER.34% + DERM.FARINAE 33% + BLOMIA TROP.33%': 'EXTRACTO ALERGÉNICO DE ÁCARO DEL POLVO',
    'EXTRACTOS ALERGÉNICOS TRATAMIENTO SUBCUTÁNEO DEPIGOID DERM.PTER.50% + DERM.FARINAE 50%': 'EXTRACTO ALERGÉNICO DE ÁCARO DEL POLVO',
    'EXTRACTOS ALERGÉNICOS TRATAMIENTO SUBCUTÁNEO DEPIGOID GRUPO GRAMINEAS 100%': 'EXTRACTO ALERGÉNICO DE ÁCARO DEL POLVO',
    'VÉSPULA GERMÁNICA 0 (VIALES 1, 2, 3, 4 Y 5)': 'EXTRACTO ALERGÉNICO DE AVISPA',
    'VÉSPULA GERMÁNICA 1 (VIALES 1, 2, 3, 4 Y 5)': 'EXTRACTO ALERGÉNICO DE AVISPA',
    'ACIDO DIMERCAPTOSUCCINICO (SUCCIMER)': 'ACIDO DIMERCAPTOSUCCINICO',
    'ALERGENO ALTERNARIA ALTERNATA': 'EXTRACTO ALERGÉNICO DE ALTERNARIA ALTERNATA',
    'ALERGENO ARTEMISIA VULGARIS': 'EXTRACTO ALERGÉNICO DE ARTEMISIA VULGARIS',
    'PROTIRELINA (HORMONA LIBERADORA DE TIROTROPINA TRH)': 'HORMONA LIBERADORA DE TIROTROPINA',
    'AVIBACTAM 0,5G': 'AVIBACTAM',
    'HORMONA LIBERADORA DE CORTICOTROPINA (CRH)': 'HORMONA LIBERADORA DE CORTICOTROPINA',
    'ROMIDEPSIN': 'ROMIDEPSINA',
    'SUCCIMER': 'ACIDO DIMERCAPTOSUCCINICO',
    'SOFOSBUVIR +VELPATASVIR+VOXILAPREVIR': 'SOFOSBUVIR/VELPATASVIR/VOXILAPREVIR',
    'EXTRACTO SECO DE LA CORTEZA DE ABEDUL BETULINA': 'BETULINA',
    'ACIDO 5 AMINOLEVULÍNICO HCL': 'ACIDO 5 AMINOLEVULÍNICO',
    'AMFOTERICINA': 'ANFOTERICINA',
    'DILUENTE': 'DILUYENTE',
    'TRASTUZUMAB': 'TRASTUZUMAB DERUXTECAN',
    'TRIENTINA CLORHIDRATO': 'TRIENTINA',
    'TRIHEXIFENIDILO HCL': 'TRIHEXIFENIDILO',
    'UBIDECARENONA (UBIQUINOL LIPOSOMAL)': 'UBIDECARENONA',
    'UBIDECARENONA 50MG (CO Q10;UBIQUINONA);': 'UBIDECARENONA',
    'UBIQUINOL': 'UBIDECARENONA',
    'UBIQUINOL (UBIDECARENONA)': 'UBIDECARENONA',
    'UBIQUINOL LIPOSOMAL COENZIMA Q 10': 'UBIDECARENONA',
    'UBIQUINOL LIPOSOMAL COENZIMA Q 10 UBIDECARENONA': 'UBIDECARENONA',
    'UBIQUINOL LIPOSOMAL CONCENTRADO': 'UBIDECARENONA',
    'VALINA': 'AMINOÁCIDOS ESENCIALES',
    'MEZCLA 6 GRAMÍNEAS': 'EXTRACTO ALERGÉNICO DE GRAMÍNEAS',
    'PERIPLANETA AMERICANA': 'EXTRACTO ALERGÉNICO DE CUCARACHA',
    'MERCAPTAMINA BITARTRATO': 'CISTEAMINA',
    'CISTEAMINA BITARTRATO': 'CISTEAMINA',
    'CISTEAMINA CLORHIDRATO': 'CISTEAMINA',
    'MERCAPTAMINA': 'CISTEAMINA'
}

reem_comer = {
    'LYOTHYRONINE SODIUM': 'LIOTHYRONINE SODIUM',
    'LYOTHYRONINE T3': 'LIOTHYRONINE SODIUM',
    'CRH (FERRING)': 'CRH FERRING',
    'POLIMERIZADO 100': '',
    'POLIMERIZADO': '',
    'E.H. RETARD': 'RETARD',
    'RETARD RAPID': 'RETARD',
    'E.H. RETARD Y RETARD RAPID': 'RETARD',
    'DIATER': 'DIATER POLIMERIZADO 100',
    'SPECTON': 'SPECTRON',
    'CYCLINEX 2': 'CYCLINEX',
    'CRYSVITA 20 MG': 'CRYSVITA',
    'BUSLERA 60': 'BUSLERA',
    'HB HUMANCRISANTASPASA': 'HB HUMAN',
    'DIATER POLIMERIZADO 100': 'DIATER POLIMERIZADO 100',
    'ONCO BCG 100': 'ONCO BCG 100',
    'ONKO BCG 100': 'ONKO BCG 100',
    'CYTALON 500': 'CYTALON',
    'K LOR CON M20': 'K LOR',
    'K LOR M20 SANDOZ': 'K LOR',
    'VITAFLOW': 'VITAFLO',
    'K LOR M20': 'K LOR',
    'CYTONINE': 'CYTOTINE',
    'CREATINA': 'CREATINA MONOHIDRATO',
    'VIATFLO': 'VITAFLO',
    'DAUNORRUBICIN': 'DAUNORUBICIN',
    'DAUNORUBICIN CITRATYE LIPOSOME INJECTION': 'DAUNORUBICIN',
    'PROGLYCIM': 'PROGLYCEM',
    'CABOMETIX': 'CABOMETYX',
    'TILLOMED': 'TILLOMED LAB',
    'PROCYSBI': 'PROCISBY',
    'TUXADO 40': 'TUXADO',
    'ROSINOX 40': 'ROSINOX',
    'ROSINOX 60': 'ROSINOX',
    'ROSINOX 80': 'ROSINOX',
    'PRICK TEST': 'PRICK',
    'RAVICIT': 'RAVICTI',
    'HAEMOCOMPLETTAN P': 'HAEMOCOMPLETTAN',
    'VYONDYS 53': 'VYONDYS',
    'K PHOS NEUTRAL': 'K PHOS',
    'ALEXOID': 'ALXOID',
    'CHEMOTECHNIQUE DIAGNOSTICS': 'CHEMOTECHNIQUE',
    'NATPAR': 'NATPARA',
    'CINRIZE': 'CINRYZE',
    'RHOPYLAC': 'RHOPHYLAC',
    'INMUNOREL': 'IMMUNOREL',
    'V IMNUNE': 'V IMMUNE',
    'IMMUGLO®': 'IMMUGLO',
    'CHRYSANTA 3937': 'CHRYSANTA',
    'MITOTAME': 'LYSODREN',
    'MITOTANE': 'LYSODREN',
    'VARAM FARMA': 'VARAN FARMA',
    'SPIRANZA': 'SPINRAZA',
    'LYMPARZA': 'LYNPARZA',
    'HB HUMAN BIOSCIENCE SAS': 'HB HUMAN',
    'HB HUMAN BIOSCIENCE': 'HB HUMAN',
    'HB HUMAN BIOSCIENCE VIDAR': 'HB HUMAN',
}

medicamentos.loc[medicamentos['nomb_comerc'] == 'ORKAMBI', 'princip_activo'] = 'LUMACAFTOR/IVACAFTOR'

# Reemplaza todas las palabras en la columna 'nombre_columna' según el diccionario
medicamentos['princip_activo'] = medicamentos['princip_activo'].replace(reem_prin)
medicamentos['nomb_comerc'] = medicamentos['nomb_comerc'].replace(reem_comer)

#print(medicamentos)

medicamentos.head()
# Out:
#   fecha_autori            tip_solic      cod_medicam  \
# 2   2024-10-25  PACIENTE ESPECIFICO  2E1032451000100
# 3   2024-10-25   MÁS DE UN PACIENTE  1A1023311000103
# 4   2024-10-25   MÁS DE UN PACIENTE  1A1024551000101
# 5   2024-10-25   MÁS DE UN PACIENTE  1A1024551000102
# 6   2024-10-25   MÁS DE UN PACIENTE  1A1023311000102
#
#                           princip_activo nomb_comerc  cant_solic  \
# 2       ELEXACAFTOR/TEZACAFTOR/IVACAFTOR    TRIKAFTA         3.0
# 3  EXTRACTO ALERGÉNICO DE APIS MELLIFERA       VENOX        10.0
# 4          EXTRACTO ALERGÉNICO DE AVISPA       VENOX        10.0
# 5          EXTRACTO ALERGÉNICO DE AVISPA       VENOX        10.0
# 6  EXTRACTO ALERGÉNICO DE APIS MELLIFERA       VENOX         5.0
#
#                                       present_comerc  \
# 2                                CAJAS X 84 TABLETAS
# 3  ESTUCHE X 1 VIAL LIOFILIZADO + 1 VIAL CON DILU...
# 4  ESTUCHE CON 1 VIAL CON LIOFILIZADO + 1 VIAL CO...
# ...

# %%
agrupado = medicamentos.groupby(['princip_activo', 'nomb_comerc']).size().reset_index(name='numero')

#agrupado = agrupado.sort_values(by='numero', ascending=False)

agrupado.to_csv('archivo.csv', index=False, encoding='utf-8')

# %%
conteo = agrupado['nomb_comerc'].value_counts().reset_index(name='num')
conteo.to_csv('conteo.csv', index=False, encoding='utf-8')

# %%
conteo.head()
# Out:
# nomb_comerc
# ALXOID                      7
# ORALTEK                     6
# DIATER POLIMERIZADO         6
# HB HUMAN                    5
# PRUEBA DE PROVOCACION BN    4
# Name: count, dtype: int64

# %%
unicos = medicamentos[['princip_activo']].drop_duplicates().sort_values(by='princip_activo')

#nicos = medicamentos[['princip_activo']].drop_duplicates()

unicos.to_csv('archivo.csv', index=False, encoding='utf-8')

# %%
# Ajusta la configuración para mostrar todas las filas
pd.set_option('display.max_rows', None)

# Muestra el DataFrame completo
print(unicos)

# Opcional: Restablece la configuración para no afectar otras visualizaciones
pd.reset_option('display.max_rows')
# Out:
#                                          princip_activo
# 4001                      177 LU CLORURO DE LUTECIO 177
# 420                      ACETATO DE MEDROXIPROGESTERONA
# 1731                               ACETATO DE MEGESTROL
# 653                             ACIDO 5 AMINOLEVULÍNICO
# 4190                                       ACIDO COLICO
# 2783                          ACIDO DIMERCAPTOSUCCINICO
# 7453                                 ACIDO LEVOMEFOLICO
# 590                                   ACIDO OBETICOLICO
# 193                             ACIDO QUENODESOXICOLICO
# 6914                                          AGANIRSEN
# 1876                                    ALCOHOL ETILICO
# 5598                                          ALECTINIB
# 1030                                           ALIMENTO
# 422                                         ALPROSTADIL
# 5233                                     AMFOTERICINA B
# 146                                           AMILORIDE
# ...

# %%
print(medicamentos.dtypes)
# Out:
# fecha_autori       object
# tip_solic          object
# cod_medicam        object
# princip_activo     object
# nomb_comerc        object
# cant_solic        float64
# present_comerc     object
# diagnostico        object
# cod_diagnos        object
# dtype: object

# %%
cartagena = cartagena[cartagena['Estrato'] != 'Sin Estrato']

replacements = {
    'Estrato 1': 1,
    'Estrato 2': 2,
    'Estrato 3': 3,
    'Estrato 4': 4,
    'Estrato 5': 5,
    'Estrato 6': 6
}

cartagena['Estrato'] = cartagena['Estrato'].replace(replacements)

cartagena = cartagena.dropna()

cartagena['Estrato'] = cartagena['Estrato'].astype(int)

# Proceso para calcular la edad
cartagena['ESTU_FECHANACIMIENTO'] = pd.to_datetime(cartagena['ESTU_FECHANACIMIENTO'], format='%d/%m/%Y', errors='coerce')
cartagena = cartagena.dropna(subset=['ESTU_FECHANACIMIENTO'])
